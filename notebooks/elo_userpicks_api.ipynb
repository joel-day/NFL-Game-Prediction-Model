# %% [markdown]
# # ELO League

# %% [markdown]
# ## Dependencies

# %% [markdown]
# ## Functions

# %% [markdown]
# ## Custom Variables

# %% [markdown]
# # ELO Standings

# %% [markdown]
# ## find data on playoff results and most recent year data. Add to website

# %% [markdown]
# ## create df of each teamyear and their record and stats aggreagtion, playoff final

# %% [markdown]
# ## create df of all team year and elo standings table to display on website

# %% [markdown]
# ## create a schedule

# %% [markdown]
# ## create a way to pull the next game in scheuld and face the teams. run this with event bridge

# %% [markdown]
# # User pick upcoming Games

# %% [markdown]
# ## add user account with cognito to store their picks

# %% [markdown]
# ## get dataframe of this upcoming years schedule

# %% [markdown]
# ## user tables to store user picks

# %% [markdown]
# # API

# %% [markdown]
# ## create an APi to access the elo standings table, the model, and database of user picks for use with pip and an API key

# %% [markdown]
# ## add ability to subscibe to API

# %% [markdown]
# # Update Website

# %% [markdown]
# ## Add ELO, user picks, and API to website
